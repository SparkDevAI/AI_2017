# %%
import pandas as pd


data = pd.read_csv('2000-2009-data.txt',sep=r"\s*", names = ["Year", "Month", "Day", "Hour", "Hurricane ID", "Name", "Lat", "Long", "Wind Speed", "Pressure"]
, header=None, index_col = False)
data.set_index('Year', inplace=True)
#df.set_index('Name', inplace=True)

data
# Out:
# C:\Users\mbarr\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
#       Month  Day  Hour  Hurricane ID     Name    Lat  Long  Wind Speed  \
# Year
# 2000      6    7    18             1      NOT  NAMED  21.0       -93.0
# 2000      6    8     0             1      NOT  NAMED  20.9       -92.8
# 2000      6    8     6             1      NOT  NAMED  20.7       -93.1
# 2000      6    8    12             1      NOT  NAMED  20.8       -93.5
# 2000      6   23     0             2      NOT  NAMED   9.5       -19.8
# 2000      6   23     6             2      NOT  NAMED   9.6       -21.0
# 2000      6   23    12             2      NOT  NAMED   9.9       -22.6
# 2000      6   23    18             2      NOT  NAMED  10.2       -24.5
# 2000      6   24     0             2      NOT  NAMED  10.1       -26.2
# 2000      6   24     6             2      NOT  NAMED   9.9       -27.8
# 2000      6   24    12             2      NOT  NAMED   9.9       -29.3
# 2000      6   24    18             2      NOT  NAMED  10.1       -30.1
# 2000      6   25     0             2      NOT  NAMED  10.1       -32.6
# 2000      6   25     6             2      NOT  NAMED  10.0       -34.2
# 2000      6   25    12             2      NOT  NAMED   9.8       -36.2
# 2000      6   25    18             2      NOT  NAMED   9.7       -38.2
# 2000      8    3    18             3  ALBERTO   10.8 -18.0        25.0
# 2000      8    4     0             3  ALBERTO   11.5 -20.1        30.0
# 2000      8    4     6             3  ALBERTO   12.0 -22.3        35.0
# 2000      8    4    12             3  ALBERTO   12.3 -23.8        35.0
# 2000      8    4    18             3  ALBERTO   12.7 -25.2        40.0
# 2000      8    5     0             3  ALBERTO   13.2 -26.7        40.0
# 2000      8    5     6             3  ALBERTO   13.7 -28.2        45.0
# 2000      8    5    12             3  ALBERTO   14.1 -29.8        45.0
# 2000      8    5    18             3  ALBERTO   14.5 -31.4        55.0
# 2000      8    6     0             3  ALBERTO   14.5 -33.2        65.0
# 2000      8    6     6             3  ALBERTO   14.6 -34.4        65.0
# 2000      8    6    12             3  ALBERTO   14.7 -35.4        70.0
# 2000      8    6    18             3  ALBERTO   15.2 -36.6        75.0
# 2000      8    7     0             3  ALBERTO   15.7 -38.1        75.0
# ...     ...  ...   ...           ...      ...    ...   ...         ...
# 2009     11    4    12            11      IDA   11.4 -81.8        35.0
# 2009     11    4    18            11      IDA   11.8 -82.3        45.0
# 2009     11    5     0            11      IDA   12.3 -82.8        55.0
# 2009     11    5     6            11      IDA   12.6 -83.3        65.0
# 2009     11    5    12            11      IDA   12.9 -83.6        70.0
# 2009     11    5    18            11      IDA   13.2 -83.8        50.0
# 2009     11    6     0            11      IDA   13.6 -83.9        35.0
# 2009     11    6     6            11      IDA   14.1 -84.0        30.0
# 2009     11    6    12            11      IDA   14.7 -83.9        30.0
# 2009     11    6    18            11      IDA   15.4 -83.9        30.0
# 2009     11    7     0            11      IDA   16.1 -84.0        30.0
# 2009     11    7     6            11      IDA   16.8 -84.0        35.0
# 2009     11    7    12            11      IDA   17.7 -84.0        55.0
# 2009     11    7    18            11      IDA   18.7 -84.1        60.0
# 2009     11    8     0            11      IDA   19.5 -84.5        70.0
# 2009     11    8     6            11      IDA   20.1 -85.3        80.0
# 2009     11    8    12            11      IDA   20.9 -85.8        85.0
# 2009     11    8    18            11      IDA   21.9 -86.2        85.0
# 2009     11    9     0            11      IDA   23.0 -86.5        90.0
# 2009     11    9     6            11      IDA   24.4 -87.5        80.0
# 2009     11    9    12            11      IDA   26.3 -88.3        60.0
# 2009     11    9    18            11      IDA   27.9 -88.6        65.0
# 2009     11    9    21            11      IDA   28.5 -88.7        75.0
# 2009     11   10     0            11      IDA   28.9 -88.7        60.0
# 2009     11   10     6            11      IDA   29.8 -88.6        50.0
# 2009     11   10     9            11      IDA   30.1 -88.3        45.0
# 2009     11   10    12            11      IDA   30.3 -88.0        35.0
# 2009     11   10    18            11      IDA   30.6 -87.2        30.0
# 2009     11   11     0            11      IDA   30.6 -86.3        25.0
# 2009     11   11     6            11      IDA   30.8 -85.5        25.0
#
#       Pressure
# Year
# 2000        25
# 2000        25
# 2000        25
# 2000        25
# 2000        25
# 2000        30
# 2000        30
# 2000        30
# 2000        30
# 2000        30
# 2000        30
# 2000        30
# 2000        30
# 2000        30
# 2000        30
# 2000        25
# 2000      1007
# 2000      1005
# 2000      1004
# 2000      1003
# 2000      1002
# 2000      1001
# 2000      1000
# 2000       999
# 2000       994
# 2000       987
# 2000       985
# 2000       983
# 2000       981
# 2000       979
# ...        ...
# 2009      1004
# 2009       998
# 2009       995
# 2009       987
# 2009       985
# 2009       996
# 2009      1003
# 2009      1005
# 2009      1006
# 2009      1007
# 2009      1006
# 2009      1004
# 2009       997
# 2009       990
# 2009       987
# 2009       984
# 2009       983
# 2009       975
# 2009       979
# 2009       988
# 2009       989
# 2009       990
# 2009       990
# 2009       993
# 2009       998
# 2009       998
# 2009       999
# 2009      1002
# 2009      1005
# 2009      1006
#
# [5066 rows x 9 columns]
